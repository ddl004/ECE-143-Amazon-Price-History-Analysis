# %%
import numpy as np
from scipy import stats
import datetime
import matplotlib.dates as mdates
from matplotlib import pyplot as plt
from workalendar.usa import UnitedStates
from operator import itemgetter
import keepa
import pandas as pd

api_key = 'e6ihvarndmd2iee2bgeg60afm06gru9242g310tb4tv1kji72u57uon4us908d5h'

api = keepa.Keepa(api_key)

# %%
class Product:
    '''
    Modularize each product to store each feature as an attribute of a class. 
    Attributes: 
        Mean, Max, Mode, Standard Deviation, Normalized Amazon time Price History
    Methods:
        Holidays overlaid, Ability to detect sales, Derivative of Price History, SCatter plot with various features
        Regression Function
    '''
    
    def __init__(self, product_dict):
        #TODO: Add more asserts
        assert isinstance(product_dict, dict)
        
        self.product_dict = product_dict
        self.amazon_price_history = product_dict['data']['AMAZON']
        
        self.df = pd.DataFrame(data=self.amazon_price_history, index=product_dict['data']['AMAZON_time'], columns=['amazon'])
        self.df = self.remove_nan(self.df)
        self.df['normalized'] = self.normalize_prices(self.df['amazon'])
        self.df['standardized'] = self.standardize_prices(self.df['amazon'])
        
#         self.mean = np.average(self.amazon_price_history)
#         self.max = max(self.amazon_price_history)
#         self.mode = stats.mode(self.amazon_price_history)
#         self.std = stats.tstd(self.amazon_price_history)
        self.mean = self.df['amazon'].mean()
        self.max = self.df['amazon'].max()
    
    def price_holiday_correlation(self, year=2018):
        #Plot the amazon time price history for the given year and overlay a graph of holidays on top of that
        year_index = [iter_date.year == year for iter_date in self.product_dict['data']['AMAZON_time']]
        year_prices = self.amazon_price_history[np.where(year_index)]
        year_dates = self.product_dict['data']['AMAZON_time'][np.where(year_index)]
        print('Number of price data points for the year %d: %d'% (year, len(year_dates)))
        
        return year_dates, year_prices

    def remove_nan(self, product):
        '''Remove nan prices from price history

        :param product: price history 
        :type product: pd.DataFrame or pd.Series
        :return: product with nan entries removed
        :rtype: pd.DataFrame or pd.Series
        '''
        assert isinstance(product, (pd.DataFrame,pd.Series))

        return product.dropna()

    def standardize_prices(self, x):
        '''Given an iterable list of prices, standardize the prices
        Data is centered at 0 mean with unit variance

        :param x: price history
        :type x: (list, np.ndarray, pd.Series)
        :return: z-score standardized price history
        :rtype: np.ndarray
        '''

        assert isinstance(x, (list, np.ndarray, pd.Series))
        assert all(~np.isnan(i) for i in x)

        return stats.zscore(x)

    def normalize_prices(self, x):
        '''Normalize an iterable list of prices to range (0,1)

        :param x: price history
        :type x: (list, np.ndarray, pd.Series)
        :return: normalized price history
        :rtype: np.ndarray
        '''
        assert isinstance(x, (list, np.ndarray, pd.Series))
        assert all(~np.isnan(i) for i in x)

        return (x-np.min(x))/(np.max(x) - np.min(x))

# %%
products_electronics_bs = np.load('product_electronics_50_price_history.npy', allow_pickle=True)

sample_product = Product(products_electronics_bs[0])

# %%
sample_product.price_holiday_correlation(2018)
# Out:
# Number of price data points for the year 2018: 761
# (array([datetime.datetime(2018, 1, 3, 3, 56),
#         datetime.datetime(2018, 1, 5, 2, 48),
#         datetime.datetime(2018, 1, 5, 3, 46),
#         datetime.datetime(2018, 1, 7, 12, 56),
#         datetime.datetime(2018, 1, 9, 0, 48),
#         datetime.datetime(2018, 1, 9, 4, 58),
#         datetime.datetime(2018, 1, 13, 21, 20),
#         datetime.datetime(2018, 1, 17, 17, 56),
#         datetime.datetime(2018, 1, 17, 19, 34),
#         datetime.datetime(2018, 1, 18, 1, 28),
#         datetime.datetime(2018, 1, 18, 2, 16),
#         datetime.datetime(2018, 1, 18, 12, 24),
#         datetime.datetime(2018, 1, 18, 13, 28),
#         datetime.datetime(2018, 1, 18, 15, 36),
#         datetime.datetime(2018, 1, 18, 18, 8),
#         datetime.datetime(2018, 1, 18, 21, 28),
#         datetime.datetime(2018, 1, 19, 0, 0),
#         datetime.datetime(2018, 1, 19, 0, 48),
#         datetime.datetime(2018, 1, 19, 2, 12),
#         datetime.datetime(2018, 1, 19, 3, 18),
#         datetime.datetime(2018, 1, 19, 4, 56),
#         datetime.datetime(2018, 1, 19, 5, 48),
#         datetime.datetime(2018, 1, 19, 12, 42),
#         datetime.datetime(2018, 1, 20, 0, 28),
#         datetime.datetime(2018, 1, 20, 1, 16),
#         datetime.datetime(2018, 1, 20, 2, 28),
#         datetime.datetime(2018, 1, 20, 3, 40),
#         datetime.datetime(2018, 1, 20, 4, 36),
#         datetime.datetime(2018, 1, 20, 5, 48),
#         datetime.datetime(2018, 1, 21, 22, 24),
#         datetime.datetime(2018, 1, 22, 3, 22),
#         datetime.datetime(2018, 1, 22, 8, 24),
#         datetime.datetime(2018, 1, 23, 13, 24),
#         datetime.datetime(2018, 1, 24, 1, 44),
#         datetime.datetime(2018, 1, 24, 2, 32),
#         datetime.datetime(2018, 1, 24, 7, 16),
#         datetime.datetime(2018, 1, 24, 8, 24),
#         datetime.datetime(2018, 1, 24, 12, 36),
#         datetime.datetime(2018, 1, 24, 17, 38),
#         datetime.datetime(2018, 1, 25, 1, 12),
#         datetime.datetime(2018, 1, 25, 2, 52),
#         datetime.datetime(2018, 1, 25, 9, 56),
#         datetime.datetime(2018, 1, 25, 17, 0),
#         datetime.datetime(2018, 1, 25, 21, 32),
#         datetime.datetime(2018, 1, 26, 0, 52),
#         datetime.datetime(2018, 1, 26, 14, 40),
#         datetime.datetime(2018, 1, 26, 16, 0),
#         datetime.datetime(2018, 1, 31, 2, 32),
#         datetime.datetime(2018, 2, 1, 22, 32),
#         datetime.datetime(2018, 2, 6, 21, 16),
#         datetime.datetime(2018, 2, 6, 23, 12),
#         datetime.datetime(2018, 2, 7, 23, 40),
#         datetime.datetime(2018, 2, 8, 3, 46),
#         datetime.datetime(2018, 2, 8, 18, 8),
#         datetime.datetime(2018, 2, 9, 10, 28),
#         datetime.datetime(2018, 2, 9, 13, 26),
#         datetime.datetime(2018, 2, 9, 14, 46),
#         datetime.datetime(2018, 2, 9, 15, 40),
#         datetime.datetime(2018, 2, 9, 16, 28),
#         datetime.datetime(2018, 2, 12, 18, 32),
#         datetime.datetime(2018, 2, 12, 20, 0),
#         datetime.datetime(2018, 2, 12, 21, 6),
#         datetime.datetime(2018, 2, 12, 22, 46),
#         datetime.datetime(2018, 2, 13, 1, 20),
#         datetime.datetime(2018, 2, 13, 5, 28),
#         datetime.datetime(2018, 2, 13, 13, 0),
#         datetime.datetime(2018, 2, 13, 15, 26),
#         datetime.datetime(2018, 2, 13, 17, 4),
#         datetime.datetime(2018, 2, 14, 14, 24),
#         datetime.datetime(2018, 2, 14, 21, 44),
#         datetime.datetime(2018, 2, 14, 23, 14),
#         datetime.datetime(2018, 2, 15, 2, 44),
#         datetime.datetime(2018, 2, 15, 4, 10),
#         datetime.datetime(2018, 2, 15, 7, 4),
#         datetime.datetime(2018, 2, 15, 8, 28),
#         datetime.datetime(2018, 2, 15, 11, 52),
#         datetime.datetime(2018, 2, 15, 15, 50),
#         datetime.datetime(2018, 2, 15, 18, 36),
#         datetime.datetime(2018, 2, 15, 19, 36),
#         datetime.datetime(2018, 2, 15, 21, 28),
#         datetime.datetime(2018, 2, 15, 22, 16),
#         datetime.datetime(2018, 2, 16, 0, 2),
#         datetime.datetime(2018, 2, 16, 1, 44),
#         datetime.datetime(2018, 2, 16, 4, 32),
#         datetime.datetime(2018, 2, 16, 7, 16),
#         datetime.datetime(2018, 2, 16, 9, 56),
#         datetime.datetime(2018, 2, 16, 11, 36),
#         datetime.datetime(2018, 2, 16, 14, 4),
#         datetime.datetime(2018, 2, 16, 15, 44),
#         datetime.datetime(2018, 2, 16, 17, 22),
#         datetime.datetime(2018, 2, 16, 19, 54),
#         datetime.datetime(2018, 2, 18, 17, 4),
#         datetime.datetime(2018, 2, 19, 16, 18),
#         datetime.datetime(2018, 2, 20, 3, 20),
#         datetime.datetime(2018, 2, 20, 11, 32),
#         datetime.datetime(2018, 2, 21, 17, 12),
#         datetime.datetime(2018, 2, 22, 20, 30),
#         datetime.datetime(2018, 2, 23, 3, 8),
#         datetime.datetime(2018, 2, 25, 19, 48),
#         datetime.datetime(2018, 2, 26, 22, 24),
#         datetime.datetime(2018, 2, 27, 15, 40),
#         datetime.datetime(2018, 3, 1, 7, 40),
#         datetime.datetime(2018, 3, 1, 8, 32),
#         datetime.datetime(2018, 3, 1, 15, 12),
#         datetime.datetime(2018, 3, 1, 17, 42),
#         datetime.datetime(2018, 3, 2, 0, 16),
#         datetime.datetime(2018, 3, 2, 1, 12),
#         datetime.datetime(2018, 3, 2, 3, 34),
#         datetime.datetime(2018, 3, 2, 5, 24),
#         datetime.datetime(2018, 3, 2, 14, 52),
#         datetime.datetime(2018, 3, 2, 16, 40),
#         datetime.datetime(2018, 3, 2, 17, 56),
#         datetime.datetime(2018, 3, 3, 1, 24),
#         datetime.datetime(2018, 3, 3, 3, 4),
#         datetime.datetime(2018, 3, 3, 5, 36),
#         datetime.datetime(2018, 3, 3, 7, 16),
#         datetime.datetime(2018, 3, 3, 10, 36),
#         datetime.datetime(2018, 3, 3, 12, 36),
#         datetime.datetime(2018, 3, 3, 14, 44),
#         datetime.datetime(2018, 3, 3, 16, 0),
#         datetime.datetime(2018, 3, 3, 18, 56),
#         datetime.datetime(2018, 3, 3, 20, 36),
#         datetime.datetime(2018, 3, 3, 22, 56),
#         datetime.datetime(2018, 3, 4, 0, 44),
#         datetime.datetime(2018, 3, 4, 2, 52),
#         datetime.datetime(2018, 3, 4, 5, 56),
#         datetime.datetime(2018, 3, 4, 10, 28),
#         datetime.datetime(2018, 3, 4, 12, 36),
#         datetime.datetime(2018, 3, 4, 14, 48),
#         datetime.datetime(2018, 3, 5, 14, 4),
#         datetime.datetime(2018, 3, 5, 20, 12),
#         datetime.datetime(2018, 3, 5, 23, 20),
#         datetime.datetime(2018, 3, 6, 1, 52),
#         datetime.datetime(2018, 3, 6, 3, 20),
#         datetime.datetime(2018, 3, 6, 6, 2),
#         datetime.datetime(2018, 3, 6, 7, 48),
#         datetime.datetime(2018, 3, 6, 10, 20),
#         datetime.datetime(2018, 3, 6, 12, 0),
#         datetime.datetime(2018, 3, 6, 15, 20),
#         datetime.datetime(2018, 3, 6, 19, 28),
#         datetime.datetime(2018, 3, 7, 0, 34),
#         datetime.datetime(2018, 3, 7, 3, 28),
#         datetime.datetime(2018, 3, 7, 4, 24),
#         datetime.datetime(2018, 3, 7, 6, 4),
#         datetime.datetime(2018, 3, 7, 7, 44),
#         datetime.datetime(2018, 3, 7, 9, 44),
#         datetime.datetime(2018, 3, 7, 14, 16),
#         datetime.datetime(2018, 3, 7, 16, 2),
#         datetime.datetime(2018, 3, 8, 2, 16),
#         datetime.datetime(2018, 3, 8, 3, 0),
#         datetime.datetime(2018, 3, 8, 5, 44),
#         datetime.datetime(2018, 3, 8, 8, 28),
#         datetime.datetime(2018, 3, 8, 9, 38),
#         datetime.datetime(2018, 3, 8, 13, 26),
#         datetime.datetime(2018, 3, 8, 15, 2),
#         datetime.datetime(2018, 3, 8, 23, 56),
#         datetime.datetime(2018, 3, 9, 2, 2),
#         datetime.datetime(2018, 3, 9, 3, 16),
#         datetime.datetime(2018, 3, 9, 5, 44),
#         datetime.datetime(2018, 3, 9, 7, 20),
#         datetime.datetime(2018, 3, 9, 9, 52),
#         datetime.datetime(2018, 3, 9, 13, 16),
#         datetime.datetime(2018, 3, 9, 14, 12),
#         datetime.datetime(2018, 3, 9, 15, 8),
#         datetime.datetime(2018, 3, 10, 1, 32),
#         datetime.datetime(2018, 3, 11, 19, 20),
#         datetime.datetime(2018, 3, 12, 0, 20),
#         datetime.datetime(2018, 3, 12, 7, 56),
#         datetime.datetime(2018, 3, 12, 13, 44),
#         datetime.datetime(2018, 3, 12, 22, 56),
#         datetime.datetime(2018, 3, 13, 0, 36),
#         datetime.datetime(2018, 3, 13, 3, 6),
#         datetime.datetime(2018, 3, 13, 5, 36),
#         datetime.datetime(2018, 3, 13, 8, 4),
#         datetime.datetime(2018, 3, 13, 9, 44),
#         datetime.datetime(2018, 3, 13, 12, 16),
#         datetime.datetime(2018, 3, 13, 13, 56),
#         datetime.datetime(2018, 3, 13, 16, 26),
#         datetime.datetime(2018, 3, 14, 1, 40),
#         datetime.datetime(2018, 3, 14, 3, 18),
#         datetime.datetime(2018, 3, 14, 5, 48),
#         datetime.datetime(2018, 3, 14, 14, 0),
#         datetime.datetime(2018, 3, 15, 1, 38),
#         datetime.datetime(2018, 3, 15, 2, 48),
#         datetime.datetime(2018, 3, 15, 5, 20),
#         datetime.datetime(2018, 3, 15, 13, 50),
#         datetime.datetime(2018, 3, 15, 18, 40),
#         datetime.datetime(2018, 3, 16, 1, 24),
#         datetime.datetime(2018, 3, 16, 14, 4),
#         datetime.datetime(2018, 3, 16, 19, 14),
#         datetime.datetime(2018, 3, 21, 14, 20),
#         datetime.datetime(2018, 3, 21, 15, 16),
#         datetime.datetime(2018, 3, 22, 0, 32),
#         datetime.datetime(2018, 3, 22, 2, 24),
#         datetime.datetime(2018, 3, 22, 3, 16),
#         datetime.datetime(2018, 3, 22, 5, 28),
#         datetime.datetime(2018, 3, 22, 7, 24),
#         datetime.datetime(2018, 3, 22, 9, 52),
#         datetime.datetime(2018, 3, 22, 12, 22),
#         datetime.datetime(2018, 3, 22, 14, 2),
#         datetime.datetime(2018, 3, 23, 0, 56),
#         datetime.datetime(2018, 3, 23, 3, 36),
#         datetime.datetime(2018, 3, 23, 5, 16),
#         datetime.datetime(2018, 3, 23, 7, 46),
#         datetime.datetime(2018, 3, 23, 10, 16),
#         datetime.datetime(2018, 3, 23, 11, 50),
#         datetime.datetime(2018, 3, 23, 14, 28),
#         datetime.datetime(2018, 3, 24, 0, 36),
#         datetime.datetime(2018, 3, 24, 3, 12),
#         datetime.datetime(2018, 3, 24, 6, 0),
#         datetime.datetime(2018, 3, 24, 7, 40),
#         datetime.datetime(2018, 3, 24, 10, 8),
#         datetime.datetime(2018, 3, 24, 11, 50),
#         datetime.datetime(2018, 3, 24, 14, 20),
#         datetime.datetime(2018, 3, 28, 22, 56),
#         datetime.datetime(2018, 3, 29, 0, 36),
#         datetime.datetime(2018, 3, 29, 3, 24),
#         datetime.datetime(2018, 3, 29, 5, 28),
#         datetime.datetime(2018, 3, 29, 7, 56),
#         datetime.datetime(2018, 3, 29, 9, 36),
#         datetime.datetime(2018, 3, 29, 12, 4),
#         datetime.datetime(2018, 3, 29, 14, 36),
#         datetime.datetime(2018, 3, 29, 17, 20),
#         datetime.datetime(2018, 3, 30, 1, 56),
#         datetime.datetime(2018, 3, 30, 3, 6),
#         datetime.datetime(2018, 3, 30, 5, 30),
#         datetime.datetime(2018, 3, 30, 8, 36),
#         datetime.datetime(2018, 3, 30, 9, 44),
#         datetime.datetime(2018, 3, 30, 12, 20),
#         datetime.datetime(2018, 3, 30, 13, 38),
#         datetime.datetime(2018, 3, 31, 0, 40),
#         datetime.datetime(2018, 3, 31, 2, 38),
#         datetime.datetime(2018, 3, 31, 6, 2),
#         datetime.datetime(2018, 3, 31, 7, 36),
#         datetime.datetime(2018, 3, 31, 9, 28),
#         datetime.datetime(2018, 3, 31, 11, 44),
#         datetime.datetime(2018, 3, 31, 14, 16),
#         datetime.datetime(2018, 3, 31, 16, 46),
#         datetime.datetime(2018, 4, 2, 12, 52),
#         datetime.datetime(2018, 4, 3, 1, 44),
#         datetime.datetime(2018, 4, 3, 2, 32),
#         datetime.datetime(2018, 4, 3, 4, 20),
#         datetime.datetime(2018, 4, 3, 6, 48),
#         datetime.datetime(2018, 4, 3, 9, 6),
#         datetime.datetime(2018, 4, 3, 11, 8),
#         datetime.datetime(2018, 4, 3, 13, 38),
#         datetime.datetime(2018, 4, 3, 20, 16),
#         datetime.datetime(2018, 4, 4, 2, 12),
#         datetime.datetime(2018, 4, 4, 3, 52),
#         datetime.datetime(2018, 4, 4, 6, 20),
#         datetime.datetime(2018, 4, 4, 8, 12),
#         datetime.datetime(2018, 4, 4, 10, 56),
#         datetime.datetime(2018, 4, 4, 12, 32),
#         datetime.datetime(2018, 4, 4, 14, 14),
#         datetime.datetime(2018, 4, 5, 1, 8),
#         datetime.datetime(2018, 4, 5, 3, 36),
#         datetime.datetime(2018, 4, 5, 5, 16),
#         datetime.datetime(2018, 4, 5, 7, 48),
#         datetime.datetime(2018, 4, 5, 9, 28),
#         datetime.datetime(2018, 4, 5, 13, 48),
#         datetime.datetime(2018, 4, 5, 14, 44),
#         datetime.datetime(2018, 4, 6, 1, 4),
#         datetime.datetime(2018, 4, 6, 3, 32),
#         datetime.datetime(2018, 4, 6, 5, 12),
#         datetime.datetime(2018, 4, 6, 7, 46),
#         datetime.datetime(2018, 4, 6, 9, 36),
#         datetime.datetime(2018, 4, 6, 14, 28),
#         datetime.datetime(2018, 4, 7, 1, 0),
#         datetime.datetime(2018, 4, 7, 3, 20),
#         datetime.datetime(2018, 4, 7, 5, 44),
#         datetime.datetime(2018, 4, 7, 8, 20),
#         datetime.datetime(2018, 4, 7, 10, 56),
#         datetime.datetime(2018, 4, 9, 13, 38),
#         datetime.datetime(2018, 4, 10, 0, 0),
#         datetime.datetime(2018, 4, 13, 14, 12),
#         datetime.datetime(2018, 4, 14, 1, 36),
#         datetime.datetime(2018, 4, 14, 3, 32),
#         datetime.datetime(2018, 4, 14, 5, 24),
#         datetime.datetime(2018, 4, 14, 7, 46),
#         datetime.datetime(2018, 4, 14, 10, 16),
#         datetime.datetime(2018, 4, 14, 11, 56),
#         datetime.datetime(2018, 4, 14, 14, 48),
#         datetime.datetime(2018, 4, 16, 14, 8),
#         datetime.datetime(2018, 4, 17, 1, 24),
#         datetime.datetime(2018, 4, 17, 3, 8),
#         datetime.datetime(2018, 4, 17, 6, 24),
#         datetime.datetime(2018, 4, 17, 10, 0),
#         datetime.datetime(2018, 4, 17, 11, 58),
#         datetime.datetime(2018, 4, 17, 13, 52),
#         datetime.datetime(2018, 4, 17, 23, 36),
#         datetime.datetime(2018, 4, 18, 1, 26),
#         datetime.datetime(2018, 4, 18, 4, 12),
#         datetime.datetime(2018, 4, 18, 5, 52),
#         datetime.datetime(2018, 4, 18, 8, 12),
#         datetime.datetime(2018, 4, 18, 10, 4),
#         datetime.datetime(2018, 4, 18, 12, 32),
#         datetime.datetime(2018, 4, 18, 15, 4),
#         datetime.datetime(2018, 4, 19, 1, 20),
#         datetime.datetime(2018, 4, 19, 2, 46),
#         datetime.datetime(2018, 4, 19, 3, 36),
#         datetime.datetime(2018, 4, 19, 4, 26),
#         datetime.datetime(2018, 4, 19, 5, 16),
#         datetime.datetime(2018, 4, 19, 7, 46),
#         datetime.datetime(2018, 4, 19, 10, 16),
#         datetime.datetime(2018, 4, 19, 11, 58),
#         datetime.datetime(2018, 4, 20, 0, 32),
#         datetime.datetime(2018, 4, 20, 3, 6),
#         datetime.datetime(2018, 4, 20, 14, 4),
#         datetime.datetime(2018, 4, 21, 1, 14),
#         datetime.datetime(2018, 4, 21, 2, 54),
#         datetime.datetime(2018, 4, 23, 15, 20),
#         datetime.datetime(2018, 4, 24, 0, 36),
#         datetime.datetime(2018, 4, 24, 3, 6),
#         datetime.datetime(2018, 4, 24, 5, 36),
#         datetime.datetime(2018, 4, 24, 7, 22),
#         datetime.datetime(2018, 4, 24, 9, 52),
#         datetime.datetime(2018, 4, 24, 11, 40),
#         datetime.datetime(2018, 4, 24, 14, 36),
#         datetime.datetime(2018, 4, 24, 18, 56),
#         datetime.datetime(2018, 4, 24, 21, 26),
#         datetime.datetime(2018, 4, 25, 3, 40),
#         datetime.datetime(2018, 4, 25, 5, 44),
#         datetime.datetime(2018, 4, 25, 7, 20),
#         datetime.datetime(2018, 4, 25, 9, 50),
#         datetime.datetime(2018, 4, 25, 15, 4),
#         datetime.datetime(2018, 4, 26, 1, 42),
#         datetime.datetime(2018, 4, 26, 4, 20),
#         datetime.datetime(2018, 4, 26, 5, 20),
#         datetime.datetime(2018, 4, 26, 7, 48),
#         datetime.datetime(2018, 4, 26, 19, 16),
#         datetime.datetime(2018, 4, 27, 0, 10),
#         datetime.datetime(2018, 4, 27, 1, 28),
#         datetime.datetime(2018, 4, 27, 3, 42),
#         datetime.datetime(2018, 4, 27, 5, 56),
#         datetime.datetime(2018, 4, 27, 7, 48),
#         datetime.datetime(2018, 4, 27, 9, 44),
#         datetime.datetime(2018, 4, 27, 14, 48),
#         datetime.datetime(2018, 4, 27, 16, 26),
#         datetime.datetime(2018, 4, 28, 1, 0),
#         datetime.datetime(2018, 4, 28, 12, 24),
#         datetime.datetime(2018, 4, 28, 18, 34),
#         datetime.datetime(2018, 4, 29, 8, 40),
#         datetime.datetime(2018, 4, 29, 13, 30),
#         datetime.datetime(2018, 4, 30, 5, 10),
#         datetime.datetime(2018, 4, 30, 17, 20),
#         datetime.datetime(2018, 5, 1, 12, 8),
#         datetime.datetime(2018, 5, 2, 0, 38),
#         datetime.datetime(2018, 5, 2, 5, 12),
#         datetime.datetime(2018, 5, 2, 12, 32),
#         datetime.datetime(2018, 5, 2, 19, 48),
#         datetime.datetime(2018, 5, 3, 7, 6),
#         datetime.datetime(2018, 5, 3, 21, 40),
#         datetime.datetime(2018, 5, 4, 13, 18),
#         datetime.datetime(2018, 5, 4, 14, 8),
#         datetime.datetime(2018, 5, 5, 5, 48),
#         datetime.datetime(2018, 5, 8, 4, 40),
#         datetime.datetime(2018, 5, 8, 5, 30),
#         datetime.datetime(2018, 5, 9, 3, 38),
#         datetime.datetime(2018, 5, 9, 4, 24),
#         datetime.datetime(2018, 5, 9, 4, 40),
#         datetime.datetime(2018, 5, 9, 5, 20),
#         datetime.datetime(2018, 5, 9, 6, 8),
#         datetime.datetime(2018, 5, 9, 13, 32),
#         datetime.datetime(2018, 5, 9, 21, 32),
#         datetime.datetime(2018, 5, 10, 5, 24),
#         datetime.datetime(2018, 5, 10, 8, 4),
#         datetime.datetime(2018, 5, 10, 16, 20),
#         datetime.datetime(2018, 5, 10, 23, 2),
#         datetime.datetime(2018, 5, 11, 0, 50),
#         datetime.datetime(2018, 5, 11, 1, 38),
#         datetime.datetime(2018, 5, 11, 4, 6),
#         datetime.datetime(2018, 5, 11, 4, 56),
#         datetime.datetime(2018, 5, 11, 5, 46),
#         datetime.datetime(2018, 5, 11, 16, 12),
#         datetime.datetime(2018, 5, 11, 19, 32),
#         datetime.datetime(2018, 5, 12, 2, 20),
#         datetime.datetime(2018, 5, 12, 2, 56),
#         datetime.datetime(2018, 5, 12, 3, 48),
#         datetime.datetime(2018, 5, 12, 4, 36),
#         datetime.datetime(2018, 5, 12, 5, 26),
#         datetime.datetime(2018, 5, 12, 6, 16),
#         datetime.datetime(2018, 5, 12, 7, 8),
#         datetime.datetime(2018, 5, 12, 7, 56),
#         datetime.datetime(2018, 5, 12, 8, 46),
#         datetime.datetime(2018, 5, 12, 9, 36),
#         datetime.datetime(2018, 5, 12, 10, 28),
#         datetime.datetime(2018, 5, 12, 11, 16),
#         datetime.datetime(2018, 5, 12, 12, 8),
#         datetime.datetime(2018, 5, 12, 14, 36),
#         datetime.datetime(2018, 5, 13, 0, 40),
#         datetime.datetime(2018, 5, 13, 2, 44),
#         datetime.datetime(2018, 5, 13, 3, 36),
#         datetime.datetime(2018, 5, 13, 4, 28),
#         datetime.datetime(2018, 5, 13, 5, 16),
#         datetime.datetime(2018, 5, 13, 6, 8),
#         datetime.datetime(2018, 5, 13, 6, 56),
#         datetime.datetime(2018, 5, 13, 7, 46),
#         datetime.datetime(2018, 5, 13, 8, 38),
#         datetime.datetime(2018, 5, 13, 9, 28),
#         datetime.datetime(2018, 5, 13, 11, 6),
#         datetime.datetime(2018, 5, 13, 11, 56),
#         datetime.datetime(2018, 5, 13, 12, 48),
#         datetime.datetime(2018, 5, 13, 13, 36),
#         datetime.datetime(2018, 5, 13, 14, 28),
#         datetime.datetime(2018, 5, 13, 15, 16),
#         datetime.datetime(2018, 5, 13, 16, 6),
#         datetime.datetime(2018, 5, 13, 16, 56),
#         datetime.datetime(2018, 5, 13, 17, 48),
#         datetime.datetime(2018, 5, 13, 18, 36),
#         datetime.datetime(2018, 5, 13, 20, 16),
#         datetime.datetime(2018, 5, 13, 21, 6),
#         datetime.datetime(2018, 5, 13, 21, 58),
#         datetime.datetime(2018, 5, 13, 22, 48),
#         datetime.datetime(2018, 5, 13, 23, 36),
#         datetime.datetime(2018, 5, 14, 0, 26),
#         datetime.datetime(2018, 5, 14, 2, 20),
#         datetime.datetime(2018, 5, 14, 19, 24),
#         datetime.datetime(2018, 5, 14, 21, 4),
#         datetime.datetime(2018, 5, 15, 3, 44),
#         datetime.datetime(2018, 5, 15, 4, 34),
#         datetime.datetime(2018, 5, 15, 8, 36),
#         datetime.datetime(2018, 5, 15, 23, 24),
#         datetime.datetime(2018, 5, 16, 1, 4),
#         datetime.datetime(2018, 5, 16, 12, 40),
#         datetime.datetime(2018, 5, 16, 21, 28),
#         datetime.datetime(2018, 5, 17, 11, 56),
#         datetime.datetime(2018, 5, 18, 5, 36),
#         datetime.datetime(2018, 5, 19, 0, 36),
#         datetime.datetime(2018, 5, 20, 6, 32),
#         datetime.datetime(2018, 5, 20, 23, 20),
#         datetime.datetime(2018, 5, 21, 5, 58),
#         datetime.datetime(2018, 5, 22, 1, 12),
#         datetime.datetime(2018, 5, 23, 15, 56),
#         datetime.datetime(2018, 5, 23, 21, 48),
#         datetime.datetime(2018, 5, 25, 16, 22),
#         datetime.datetime(2018, 5, 25, 18, 16),
#         datetime.datetime(2018, 5, 26, 23, 54),
#         datetime.datetime(2018, 5, 27, 0, 48),
#         datetime.datetime(2018, 5, 27, 1, 38),
#         datetime.datetime(2018, 5, 27, 2, 32),
#         datetime.datetime(2018, 5, 27, 4, 16),
#         datetime.datetime(2018, 5, 27, 5, 12),
#         datetime.datetime(2018, 5, 29, 14, 58),
#         datetime.datetime(2018, 5, 29, 15, 50),
#         datetime.datetime(2018, 5, 29, 20, 8),
#         datetime.datetime(2018, 5, 30, 0, 16),
#         datetime.datetime(2018, 6, 3, 12, 22),
#         datetime.datetime(2018, 6, 5, 1, 24),
#         datetime.datetime(2018, 6, 6, 0, 36),
#         datetime.datetime(2018, 6, 6, 2, 50),
#         datetime.datetime(2018, 6, 6, 5, 56),
#         datetime.datetime(2018, 6, 6, 19, 46),
#         datetime.datetime(2018, 6, 6, 23, 8),
#         datetime.datetime(2018, 6, 12, 6, 32),
#         datetime.datetime(2018, 6, 26, 16, 38),
#         datetime.datetime(2018, 6, 27, 4, 52),
#         datetime.datetime(2018, 6, 28, 19, 54),
#         datetime.datetime(2018, 6, 29, 0, 4),
#         datetime.datetime(2018, 6, 29, 7, 34),
#         datetime.datetime(2018, 6, 30, 11, 56),
#         datetime.datetime(2018, 6, 30, 22, 46),
#         datetime.datetime(2018, 7, 2, 4, 20),
#         datetime.datetime(2018, 7, 4, 18, 10),
#         datetime.datetime(2018, 7, 6, 7, 40),
#         datetime.datetime(2018, 7, 21, 8, 26),
#         datetime.datetime(2018, 7, 22, 7, 48),
#         datetime.datetime(2018, 7, 24, 2, 0),
#         datetime.datetime(2018, 7, 24, 4, 28),
#         datetime.datetime(2018, 7, 24, 5, 20),
#         datetime.datetime(2018, 7, 24, 6, 10),
#         datetime.datetime(2018, 7, 24, 7, 0),
#         datetime.datetime(2018, 7, 24, 22, 56),
#         datetime.datetime(2018, 7, 25, 3, 56),
#         datetime.datetime(2018, 7, 25, 4, 44),
#         datetime.datetime(2018, 7, 25, 6, 4),
#         datetime.datetime(2018, 7, 25, 6, 24),
#         datetime.datetime(2018, 7, 25, 15, 4),
#         datetime.datetime(2018, 7, 26, 2, 38),
#         datetime.datetime(2018, 7, 26, 3, 28),
#         datetime.datetime(2018, 7, 26, 4, 16),
#         datetime.datetime(2018, 7, 26, 5, 18),
#         datetime.datetime(2018, 7, 26, 6, 8),
#         datetime.datetime(2018, 7, 27, 11, 16),
#         datetime.datetime(2018, 7, 27, 20, 44),
#         datetime.datetime(2018, 7, 28, 2, 34),
#         datetime.datetime(2018, 7, 28, 3, 26),
#         datetime.datetime(2018, 7, 28, 15, 6),
#         datetime.datetime(2018, 7, 28, 15, 56),
#         datetime.datetime(2018, 7, 28, 16, 46),
#         datetime.datetime(2018, 7, 28, 17, 36),
#         datetime.datetime(2018, 7, 28, 18, 26),
#         datetime.datetime(2018, 7, 28, 19, 16),
#         datetime.datetime(2018, 7, 28, 20, 6),
#         datetime.datetime(2018, 7, 28, 20, 56),
#         datetime.datetime(2018, 7, 28, 22, 0),
#         datetime.datetime(2018, 7, 28, 23, 0),
#         datetime.datetime(2018, 7, 28, 23, 40),
#         datetime.datetime(2018, 7, 29, 2, 56),
#         datetime.datetime(2018, 7, 29, 3, 44),
#         datetime.datetime(2018, 7, 29, 3, 46),
#         datetime.datetime(2018, 7, 29, 4, 36),
#         datetime.datetime(2018, 7, 29, 5, 26),
#         datetime.datetime(2018, 7, 29, 6, 16),
#         datetime.datetime(2018, 7, 29, 13, 4),
#         datetime.datetime(2018, 7, 29, 18, 4),
#         datetime.datetime(2018, 7, 30, 2, 24),
#         datetime.datetime(2018, 7, 30, 3, 14),
#         datetime.datetime(2018, 7, 30, 4, 4),
#         datetime.datetime(2018, 7, 30, 5, 48),
#         datetime.datetime(2018, 7, 30, 6, 34),
#         datetime.datetime(2018, 7, 30, 20, 48),
#         datetime.datetime(2018, 8, 1, 4, 28),
#         datetime.datetime(2018, 8, 1, 5, 0),
#         datetime.datetime(2018, 8, 1, 5, 52),
#         datetime.datetime(2018, 8, 1, 6, 40),
#         datetime.datetime(2018, 8, 1, 7, 32),
#         datetime.datetime(2018, 8, 1, 8, 20),
#         datetime.datetime(2018, 8, 1, 9, 12),
#         datetime.datetime(2018, 8, 1, 10, 56),
#         datetime.datetime(2018, 8, 1, 12, 36),
#         datetime.datetime(2018, 8, 1, 13, 36),
#         datetime.datetime(2018, 8, 1, 15, 32),
#         datetime.datetime(2018, 8, 1, 16, 20),
#         datetime.datetime(2018, 8, 1, 17, 10),
#         datetime.datetime(2018, 8, 1, 18, 0),
#         datetime.datetime(2018, 8, 1, 18, 48),
#         datetime.datetime(2018, 8, 1, 19, 40),
#         datetime.datetime(2018, 8, 1, 20, 28),
#         datetime.datetime(2018, 8, 1, 21, 20),
#         datetime.datetime(2018, 8, 1, 22, 10),
#         datetime.datetime(2018, 8, 1, 23, 0),
#         datetime.datetime(2018, 8, 4, 3, 0),
#         datetime.datetime(2018, 8, 4, 3, 52),
#         datetime.datetime(2018, 8, 5, 18, 28),
#         datetime.datetime(2018, 8, 6, 5, 20),
#         datetime.datetime(2018, 8, 13, 12, 38),
#         datetime.datetime(2018, 8, 14, 13, 56),
#         datetime.datetime(2018, 8, 14, 15, 42),
#         datetime.datetime(2018, 8, 17, 1, 18),
#         datetime.datetime(2018, 8, 17, 2, 56),
#         datetime.datetime(2018, 8, 17, 3, 48),
#         datetime.datetime(2018, 8, 17, 4, 40),
#         datetime.datetime(2018, 8, 17, 5, 28),
#         datetime.datetime(2018, 8, 17, 6, 20),
#         datetime.datetime(2018, 8, 17, 7, 8),
#         datetime.datetime(2018, 8, 19, 15, 24),
#         datetime.datetime(2018, 8, 19, 16, 14),
#         datetime.datetime(2018, 8, 19, 17, 4),
#         datetime.datetime(2018, 8, 19, 17, 52),
#         datetime.datetime(2018, 8, 19, 18, 46),
#         datetime.datetime(2018, 8, 20, 19, 50),
#         datetime.datetime(2018, 8, 20, 21, 30),
#         datetime.datetime(2018, 8, 20, 22, 20),
#         datetime.datetime(2018, 8, 20, 23, 8),
#         datetime.datetime(2018, 8, 23, 2, 36),
#         datetime.datetime(2018, 8, 23, 3, 26),
#         datetime.datetime(2018, 8, 23, 4, 16),
#         datetime.datetime(2018, 8, 23, 5, 6),
#         datetime.datetime(2018, 8, 23, 5, 56),
#         datetime.datetime(2018, 8, 24, 2, 38),
#         datetime.datetime(2018, 8, 24, 2, 50),
#         datetime.datetime(2018, 8, 24, 3, 42),
#         datetime.datetime(2018, 8, 24, 4, 32),
#         datetime.datetime(2018, 8, 24, 5, 22),
#         datetime.datetime(2018, 8, 24, 13, 40),
#         datetime.datetime(2018, 8, 25, 1, 48),
#         datetime.datetime(2018, 8, 25, 2, 38),
#         datetime.datetime(2018, 8, 25, 3, 30),
#         datetime.datetime(2018, 8, 25, 4, 20),
#         datetime.datetime(2018, 8, 28, 2, 36),
#         datetime.datetime(2018, 8, 28, 3, 48),
#         datetime.datetime(2018, 8, 29, 4, 0),
#         datetime.datetime(2018, 8, 29, 4, 50),
#         datetime.datetime(2018, 9, 2, 16, 16),
#         datetime.datetime(2018, 9, 3, 14, 56),
#         datetime.datetime(2018, 9, 3, 17, 46),
#         datetime.datetime(2018, 9, 4, 4, 36),
#         datetime.datetime(2018, 9, 4, 18, 52),
#         datetime.datetime(2018, 9, 4, 23, 52),
#         datetime.datetime(2018, 9, 5, 17, 32),
#         datetime.datetime(2018, 9, 6, 22, 48),
#         datetime.datetime(2018, 9, 7, 19, 54),
#         datetime.datetime(2018, 9, 8, 0, 4),
#         datetime.datetime(2018, 9, 8, 21, 44),
#         datetime.datetime(2018, 9, 8, 22, 36),
#         datetime.datetime(2018, 9, 9, 0, 16),
#         datetime.datetime(2018, 9, 9, 8, 36),
#         datetime.datetime(2018, 9, 11, 18, 0),
#         datetime.datetime(2018, 9, 15, 12, 30),
#         datetime.datetime(2018, 9, 15, 19, 12),
#         datetime.datetime(2018, 9, 16, 1, 50),
#         datetime.datetime(2018, 9, 16, 3, 28),
#         datetime.datetime(2018, 9, 16, 4, 20),
#         datetime.datetime(2018, 9, 20, 0, 36),
#         datetime.datetime(2018, 9, 21, 12, 12),
#         datetime.datetime(2018, 9, 21, 16, 20),
#         datetime.datetime(2018, 9, 23, 13, 32),
#         datetime.datetime(2018, 9, 23, 15, 52),
#         datetime.datetime(2018, 9, 25, 17, 36),
#         datetime.datetime(2018, 9, 26, 3, 40),
#         datetime.datetime(2018, 9, 26, 4, 30),
#         datetime.datetime(2018, 9, 26, 5, 20),
#         datetime.datetime(2018, 9, 26, 6, 10),
#         datetime.datetime(2018, 9, 26, 9, 30),
#         datetime.datetime(2018, 9, 26, 19, 36),
#         datetime.datetime(2018, 9, 27, 4, 46),
#         datetime.datetime(2018, 9, 27, 5, 36),
#         datetime.datetime(2018, 9, 27, 11, 12),
#         datetime.datetime(2018, 9, 27, 11, 28),
#         datetime.datetime(2018, 9, 27, 12, 20),
#         datetime.datetime(2018, 9, 27, 15, 40),
#         datetime.datetime(2018, 9, 28, 5, 0),
#         datetime.datetime(2018, 9, 29, 11, 52),
#         datetime.datetime(2018, 9, 30, 17, 56),
#         datetime.datetime(2018, 10, 3, 4, 46),
#         datetime.datetime(2018, 10, 3, 5, 34),
#         datetime.datetime(2018, 10, 3, 6, 28),
#         datetime.datetime(2018, 10, 3, 7, 18),
#         datetime.datetime(2018, 10, 3, 10, 40),
#         datetime.datetime(2018, 10, 7, 2, 48),
#         datetime.datetime(2018, 10, 8, 2, 58),
#         datetime.datetime(2018, 10, 8, 3, 48),
#         datetime.datetime(2018, 10, 9, 17, 20),
#         datetime.datetime(2018, 10, 10, 2, 58),
#         datetime.datetime(2018, 10, 10, 4, 38),
#         datetime.datetime(2018, 10, 11, 14, 24),
#         datetime.datetime(2018, 10, 14, 3, 28),
#         datetime.datetime(2018, 10, 14, 20, 8),
#         datetime.datetime(2018, 10, 14, 23, 32),
#         datetime.datetime(2018, 10, 15, 0, 20),
#         datetime.datetime(2018, 10, 21, 3, 24),
#         datetime.datetime(2018, 10, 21, 5, 54),
#         datetime.datetime(2018, 10, 21, 16, 44),
#         datetime.datetime(2018, 10, 21, 23, 48),
#         datetime.datetime(2018, 10, 22, 3, 36),
#         datetime.datetime(2018, 10, 22, 6, 4),
#         datetime.datetime(2018, 10, 24, 3, 40),
#         datetime.datetime(2018, 10, 24, 4, 4),
#         datetime.datetime(2018, 10, 24, 5, 22),
#         datetime.datetime(2018, 10, 24, 6, 12),
#         datetime.datetime(2018, 10, 24, 7, 0),
#         datetime.datetime(2018, 10, 25, 2, 32),
#         datetime.datetime(2018, 10, 25, 3, 28),
#         datetime.datetime(2018, 10, 25, 4, 20),
#         datetime.datetime(2018, 10, 25, 6, 16),
#         datetime.datetime(2018, 10, 25, 7, 26),
#         datetime.datetime(2018, 10, 26, 2, 50),
#         datetime.datetime(2018, 10, 26, 3, 40),
#         datetime.datetime(2018, 10, 26, 3, 56),
#         datetime.datetime(2018, 10, 26, 4, 30),
#         datetime.datetime(2018, 10, 26, 5, 20),
#         datetime.datetime(2018, 10, 26, 7, 0),
#         datetime.datetime(2018, 10, 29, 0, 0),
#         datetime.datetime(2018, 10, 29, 0, 48),
#         datetime.datetime(2018, 10, 29, 1, 40),
#         datetime.datetime(2018, 10, 29, 7, 14),
#         datetime.datetime(2018, 10, 29, 13, 52),
#         datetime.datetime(2018, 10, 31, 5, 32),
#         datetime.datetime(2018, 10, 31, 6, 30),
#         datetime.datetime(2018, 10, 31, 7, 24),
#         datetime.datetime(2018, 10, 31, 18, 50),
#         datetime.datetime(2018, 10, 31, 21, 22),
#         datetime.datetime(2018, 11, 1, 3, 42),
#         datetime.datetime(2018, 11, 1, 4, 4),
#         datetime.datetime(2018, 11, 1, 4, 16),
#         datetime.datetime(2018, 11, 1, 4, 56),
#         datetime.datetime(2018, 11, 1, 6, 36),
#         datetime.datetime(2018, 11, 1, 12, 28),
#         datetime.datetime(2018, 11, 2, 3, 16),
#         datetime.datetime(2018, 11, 2, 4, 4),
#         datetime.datetime(2018, 11, 2, 4, 56),
#         datetime.datetime(2018, 11, 2, 6, 34),
#         datetime.datetime(2018, 11, 2, 9, 54),
#         datetime.datetime(2018, 11, 3, 2, 32),
#         datetime.datetime(2018, 11, 3, 3, 24),
#         datetime.datetime(2018, 11, 3, 10, 54),
#         datetime.datetime(2018, 11, 3, 11, 44),
#         datetime.datetime(2018, 11, 3, 14, 18),
#         datetime.datetime(2018, 11, 3, 16, 0),
#         datetime.datetime(2018, 11, 3, 16, 48),
#         datetime.datetime(2018, 11, 3, 17, 38),
#         datetime.datetime(2018, 11, 3, 19, 20),
#         datetime.datetime(2018, 11, 3, 21, 4),
#         datetime.datetime(2018, 11, 4, 3, 20),
#         datetime.datetime(2018, 11, 4, 4, 10),
#         datetime.datetime(2018, 11, 4, 7, 36),
#         datetime.datetime(2018, 11, 4, 20, 12),
#         datetime.datetime(2018, 11, 9, 9, 0),
#         datetime.datetime(2018, 11, 10, 8, 52),
#         datetime.datetime(2018, 11, 11, 0, 30),
#         datetime.datetime(2018, 11, 12, 17, 22),
#         datetime.datetime(2018, 11, 14, 4, 24),
#         datetime.datetime(2018, 11, 14, 7, 44),
#         datetime.datetime(2018, 11, 15, 4, 18),
#         datetime.datetime(2018, 11, 15, 20, 42),
#         datetime.datetime(2018, 11, 16, 1, 52),
#         datetime.datetime(2018, 11, 16, 19, 34),
#         datetime.datetime(2018, 11, 19, 0, 18),
#         datetime.datetime(2018, 11, 19, 17, 34),
#         datetime.datetime(2018, 11, 19, 19, 2),
#         datetime.datetime(2018, 11, 19, 21, 6),
#         datetime.datetime(2018, 11, 20, 0, 56),
#         datetime.datetime(2018, 11, 20, 18, 40),
#         datetime.datetime(2018, 11, 21, 9, 4),
#         datetime.datetime(2018, 11, 21, 19, 24),
#         datetime.datetime(2018, 11, 23, 8, 32),
#         datetime.datetime(2018, 11, 24, 14, 8),
#         datetime.datetime(2018, 11, 27, 18, 28),
#         datetime.datetime(2018, 11, 27, 22, 24),
#         datetime.datetime(2018, 11, 28, 1, 28),
#         datetime.datetime(2018, 11, 28, 4, 20),
#         datetime.datetime(2018, 11, 28, 16, 14),
#         datetime.datetime(2018, 11, 28, 20, 36),
#         datetime.datetime(2018, 12, 1, 19, 8),
#         datetime.datetime(2018, 12, 2, 15, 20),
#         datetime.datetime(2018, 12, 3, 8, 10),
#         datetime.datetime(2018, 12, 7, 8, 14),
#         datetime.datetime(2018, 12, 7, 9, 2),
#         datetime.datetime(2018, 12, 8, 3, 8),
#         datetime.datetime(2018, 12, 8, 10, 48),
#         datetime.datetime(2018, 12, 8, 11, 40),
#         datetime.datetime(2018, 12, 8, 18, 0),
#         datetime.datetime(2018, 12, 8, 23, 10),
#         datetime.datetime(2018, 12, 9, 0, 52),
#         datetime.datetime(2018, 12, 9, 6, 4),
#         datetime.datetime(2018, 12, 9, 18, 56),
#         datetime.datetime(2018, 12, 9, 23, 32),
#         datetime.datetime(2018, 12, 10, 5, 10),
#         datetime.datetime(2018, 12, 10, 8, 36),
#         datetime.datetime(2018, 12, 11, 17, 0),
#         datetime.datetime(2018, 12, 11, 17, 50),
#         datetime.datetime(2018, 12, 11, 18, 40),
#         datetime.datetime(2018, 12, 11, 19, 32),
#         datetime.datetime(2018, 12, 11, 22, 38),
#         datetime.datetime(2018, 12, 11, 23, 6),
#         datetime.datetime(2018, 12, 11, 23, 46),
#         datetime.datetime(2018, 12, 12, 1, 26),
#         datetime.datetime(2018, 12, 12, 3, 22),
#         datetime.datetime(2018, 12, 12, 5, 4),
#         datetime.datetime(2018, 12, 12, 6, 30),
#         datetime.datetime(2018, 12, 12, 8, 56),
#         datetime.datetime(2018, 12, 12, 10, 46),
#         datetime.datetime(2018, 12, 12, 12, 0),
#         datetime.datetime(2018, 12, 12, 12, 26),
#         datetime.datetime(2018, 12, 12, 14, 30),
#         datetime.datetime(2018, 12, 12, 16, 48),
#         datetime.datetime(2018, 12, 15, 8, 12),
#         datetime.datetime(2018, 12, 16, 8, 4),
#         datetime.datetime(2018, 12, 18, 18, 12),
#         datetime.datetime(2018, 12, 19, 10, 50),
#         datetime.datetime(2018, 12, 20, 11, 26),
#         datetime.datetime(2018, 12, 21, 20, 34),
#         datetime.datetime(2018, 12, 22, 8, 16),
#         datetime.datetime(2018, 12, 24, 3, 42),
#         datetime.datetime(2018, 12, 24, 8, 4),
#         datetime.datetime(2018, 12, 24, 22, 16),
#         datetime.datetime(2018, 12, 27, 10, 12),
#         datetime.datetime(2018, 12, 28, 14, 28),
#         datetime.datetime(2018, 12, 28, 17, 22),
#         datetime.datetime(2018, 12, 28, 21, 0),
#         datetime.datetime(2018, 12, 29, 3, 0)], dtype=object),
#  array([106.99, 129.  ,  99.  , 109.99, 108.99,  99.  ,  98.99, 100.09,
#         105.99, 103.85,  98.99, 116.89, 101.06,  99.95, 116.87, 129.  ,
#         124.  , 122.75, 113.14, 107.52, 103.22,  98.99, 123.98, 121.49,
#         117.83, 107.5 , 102.15,  99.06,  98.99,  94.99,  98.97,  98.99,
#         105.99, 100.73, 104.91, 100.73,  98.99, 105.99, 104.99, 100.81,
#          98.99, 104.97, 109.  , 114.  , 112.99, 111.44, 111.  , 128.98,
#         129.  , 126.  , 122.  , 119.  , 115.  ,  97.  , 114.  , 111.  ,
#         108.  , 107.  , 105.  , 118.86, 118.  , 117.  , 116.  , 115.  ,
#         114.  , 117.8 , 117.  , 115.  , 128.  , 127.  , 124.99, 119.  ,
#         117.8 , 116.61, 115.43, 115.  , 117.  , 116.  , 115.  , 128.98,
#         127.  , 126.  , 124.73, 121.76, 120.53, 119.31, 118.1 , 116.9 ,
#         115.  , 114.  , 109.99, 108.  , 109.97, 109.  , 108.  , 107.  ,
#         109.  , 108.  , 107.  , 108.  , 107.44, 107.98, 108.  , 109.97,
#         109.99, 111.14, 109.99, 108.87, 108.  , 111.14, 128.98, 129.  ,
#         127.69, 126.4 , 125.12, 123.85, 122.59, 121.35, 120.12, 118.9 ,
#         117.69, 116.5 , 115.32, 114.15, 112.99, 111.84, 109.59, 108.48,
#         108.  , 128.98, 129.  , 125.  , 123.74, 113.82, 112.67, 111.53,
#         110.4 , 109.28, 114.99, 121.99, 119.  , 116.61, 115.99, 114.82,
#         113.66, 112.51, 115.97, 121.99, 118.79, 116.81, 115.63, 114.46,
#         113.3 , 108.  , 114.44, 121.99, 120.75, 119.53, 118.32, 117.12,
#         115.93, 114.75, 126.99, 120.  , 119.  , 118.  , 118.98, 119.  ,
#         129.  , 125.99, 124.71, 123.45, 122.2 , 120.96, 119.73, 119.  ,
#         125.99, 122.2 , 120.96, 119.73, 119.  , 122.2 , 120.96, 119.73,
#         119.  , 122.2 , 119.73, 119.  , 119.73, 119.  , 128.97, 128.99,
#         127.68, 126.99, 125.7 , 124.43, 123.17, 121.92, 120.68, 126.99,
#         125.7 , 124.43, 123.17, 121.92, 120.68, 119.46, 126.99, 125.7 ,
#         124.43, 123.17, 121.92, 120.68, 119.46, 119.  , 126.99, 125.7 ,
#         124.43, 123.17, 121.92, 120.68, 119.46, 126.99, 129.  , 127.69,
#         126.4 , 125.12, 123.85, 122.59, 121.35, 129.  , 127.7 , 126.41,
#         125.13, 123.86, 122.6 , 121.36, 120.13, 119.  , 128.98, 126.99,
#         125.7 , 124.43, 123.17, 121.92, 120.68, 126.99, 125.  , 123.74,
#         122.49, 121.25, 120.02, 119.  , 124.98, 125.  , 123.74, 122.49,
#         121.25, 120.02, 119.  , 124.98, 125.  , 123.74, 122.49, 121.25,
#         120.02, 119.  , 125.  , 123.73, 122.48, 121.24, 120.01, 119.  ,
#         125.  , 119.  , 126.99, 125.7 , 124.43, 123.17, 121.92, 120.68,
#         119.46, 119.  , 126.99, 125.7 , 124.43, 123.17, 120.68, 119.46,
#         126.99, 129.  , 127.69, 126.4 , 125.12, 123.85, 122.59, 121.35,
#         129.  , 127.69, 126.4 , 126.38, 126.2 , 124.81, 123.54, 122.29,
#         121.05, 119.82, 119.  , 121.05, 119.82, 119.  , 126.99, 125.7 ,
#         124.43, 123.17, 121.92, 120.68, 119.46, 126.99, 129.  , 123.17,
#         121.92, 120.68, 119.46, 119.  , 123.17, 121.92, 120.68, 119.46,
#         119.  , 120.68, 123.02, 121.78, 120.55, 119.33, 118.12, 118.  ,
#         123.02, 121.89, 117.39, 117.98, 117.22, 116.08, 117.12, 117.98,
#         117.  , 116.9 , 116.98, 116.9 , 116.8 , 117.93, 116.8 , 110.38,
#         104.31, 105.46, 124.99, 124.87, 124.99, 124.93, 124.77, 124.71,
#         124.57, 129.  , 124.99, 129.  , 128.74, 128.66, 121.81, 126.24,
#         128.4 , 128.38, 128.28, 128.1 , 128.14, 128.12, 128.1 , 127.78,
#         127.66, 127.48, 127.32, 127.16, 127.  , 126.82, 126.66, 126.48,
#         126.32, 126.14, 127.22, 128.3 , 128.98, 128.14, 127.98, 127.92,
#         127.9 , 127.82, 127.8 , 127.74, 127.72, 127.64, 127.56, 127.42,
#         127.38, 127.3 , 127.24, 127.16, 127.12, 127.04, 126.96, 126.92,
#         126.86, 126.74, 126.66, 126.6 , 126.52, 126.46, 126.11, 125.98,
#         122.25, 125.98, 123.68, 124.97, 124.99, 126.11, 124.99, 121.12,
#         124.99, 122.12, 129.  , 117.93, 117.9 , 116.8 , 116.79, 116.78,
#         123.13, 116.78, 117.91, 116.78, 116.13, 114.99,  99.85,  96.  ,
#          92.03, 116.78, 114.99, 116.78, 116.  , 129.  , 109.99, 107.2 ,
#         102.42, 107.2 , 108.39, 107.24, 109.99, 129.  , 128.99, 129.  ,
#         128.99, 129.  , 128.99, 129.  , 128.99, 129.  , 127.12, 129.  ,
#         128.98, 129.  , 128.94, 128.92, 128.78, 128.62, 128.66, 129.  ,
#         128.9 , 128.84, 128.56, 128.6 , 129.  , 128.9 , 128.74, 128.58,
#         129.  , 128.97, 128.99, 128.  , 127.9 , 129.  , 127.68, 127.48,
#         127.3 , 127.12, 126.94, 126.78, 126.6 , 126.44, 126.22, 126.02,
#         129.  , 125.88, 125.72, 125.7 , 125.57, 125.49, 125.57, 125.55,
#         125.53, 125.39, 129.  , 125.45, 125.39, 125.45, 125.43, 125.15,
#         125.01, 124.85, 124.8 , 124.7 , 124.55, 124.35, 124.  , 123.7 ,
#         123.5 , 123.1 , 122.95, 122.75, 122.6 , 122.45, 122.25, 122.1 ,
#         121.95, 121.75, 125.43, 125.35, 125.43, 116.49, 125.43, 116.49,
#         125.43, 116.49, 129.  , 128.3 , 128.06, 127.84, 127.64, 127.52,
#         129.  , 128.92, 128.78, 128.62, 128.44, 129.  , 125.47, 125.45,
#         125.39, 129.  , 128.94, 128.76, 128.6 , 128.44, 129.  , 128.94,
#         128.9 , 128.72, 128.54, 129.  , 128.52, 128.5 , 128.3 , 128.08,
#         128.52, 128.5 , 128.52, 128.46, 128.52, 128.51, 128.48, 127.95,
#         127.94, 126.48, 125.95, 125.  , 125.95, 128.99, 126.32, 125.99,
#         125.88, 121.14, 120.  , 129.  , 125.84, 119.99, 119.97, 110.  ,
#         129.  , 111.15, 110.  , 129.  , 108.97, 114.47, 128.98, 128.84,
#         128.68, 128.5 , 128.42, 129.  , 128.99, 129.  , 128.98, 128.99,
#         129.  , 128.99, 128.88, 128.86,  99.99, 128.88, 128.72, 128.58,
#         129.  , 128.86, 128.88, 107.  , 106.  , 107.  , 128.88, 128.74,
#         128.78, 128.8 , 104.  , 128.8 , 111.  , 128.78, 111.  , 128.76,
#         128.78, 106.  , 125.  , 128.78, 128.74, 128.72, 128.7 , 128.6 ,
#         128.78, 128.76, 128.74, 128.66, 128.62, 128.78, 128.74, 128.58,
#         128.54, 128.44, 129.  , 128.78, 128.64, 128.5 , 129.  , 128.76,
#         128.78, 128.62, 128.44, 128.76, 128.78, 128.76, 128.6 , 128.54,
#         128.48, 129.  , 128.76, 128.78, 128.62, 128.44, 129.  , 128.76,
#         128.78, 128.74, 128.7 , 128.66, 128.62, 128.58, 128.56, 128.52,
#         128.5 , 129.  , 128.74, 128.72, 106.  , 125.  , 128.74, 128.72,
#         128.73, 128.7 , 128.69, 129.  , 128.67, 128.69, 128.6 , 128.5 ,
#         128.25, 127.99, 127.29, 125.  , 124.  , 123.  , 120.  , 119.99,
#         119.  ,  89.  ,  89.99,  99.99, 119.  , 126.99, 128.88, 129.  ,
#         126.99, 119.99, 116.95, 119.99, 119.97, 119.  , 118.99, 116.43,
#         115.9 , 118.97, 117.  , 115.83, 109.99, 108.91,  89.  , 108.91,
#         109.99, 109.97, 109.96, 109.95, 109.94, 109.93, 109.92, 109.91,
#         109.9 , 109.89, 109.88, 109.86, 109.85, 109.84, 109.83, 109.82,
#         109.81, 109.99,  89.  , 105.  , 104.  , 103.  , 105.  , 104.99,
#          89.99,  88.  , 105.  ,  99.99,  95.55,  96.52,  95.55,  95.45,
#          95.55]))

# %%
print(len(products_electronics_bs))
print(products_electronics_bs[2].keys())
# Out:
# 50
# dict_keys(['csv', 'categories', 'imagesCSV', 'manufacturer', 'title', 'lastUpdate', 'lastPriceChange', 'rootCategory', 'productType', 'parentAsin', 'variationCSV', 'asin', 'domainId', 'type', 'hasReviews', 'ean', 'upc', 'mpn', 'trackingSince', 'brand', 'label', 'department', 'publisher', 'productGroup', 'partNumber', 'studio', 'genre', 'model', 'color', 'size', 'edition', 'platform', 'format', 'packageHeight', 'packageLength', 'packageWidth', 'packageWeight', 'packageQuantity', 'isAdultProduct', 'isEligibleForTradeIn', 'isEligibleForSuperSaverShipping', 'offers', 'buyBoxSellerIdHistory', 'isRedirectASIN', 'isSNS', 'author', 'binding', 'numberOfItems', 'numberOfPages', 'publicationDate', 'releaseDate', 'languages', 'lastRatingUpdate', 'ebayListingIds', 'lastEbayUpdate', 'eanList', 'upcList', 'liveOffersOrder', 'frequentlyBoughtTogether', 'features', 'description', 'hazardousMaterialType', 'promotions', 'newPriceIsMAP', 'coupon', 'availabilityAmazon', 'listedSince', 'fbaFees', 'variations', 'itemHeight', 'itemLength', 'itemWidth', 'itemWeight', 'stats', 'offersSuccessful', 'g', 'categoryTree', 'data'])

# %%
print(products_electronics_bs[2]['data'].keys())
# Out:
# dict_keys(['AMAZON_time', 'AMAZON', 'NEW_time', 'NEW', 'USED_time', 'USED', 'SALES_time', 'SALES', 'LISTPRICE_time', 'LISTPRICE', 'REFURBISHED_time', 'REFURBISHED', 'COUNT_NEW_time', 'COUNT_NEW', 'COUNT_USED_time', 'COUNT_USED', 'COUNT_REFURBISHED_time', 'COUNT_REFURBISHED'])

# %%
num = 49
# keepa.plot_product(products_electronics_bs[num])
plt.plot(products_electronics_bs[num]['data']['AMAZON_time'], np.log(products_electronics_bs[num]['data']['AMAZON']))
# print(np.nanmean(products_electronics_bs[num]['data']['AMAZON']))
# print(np.nanmax(products_electronics_bs[num]['data']['AMAZON']))
# print(np.nanmin(products_electronics_bs[num]['data']['AMAZON']))

# %%
from scipy import stats

def remove_nan(product):
    '''Remove nan prices from price history
    
    :param product: price history 
    :type product: pd.DataFrame or pd.Series
    :return: product with nan entries removed
    :rtype: pd.DataFrame or pd.Series
    '''
    assert isinstance(product, (pd.DataFrame,pd.Series))

    return product.dropna()

def standardize_prices(x):
    '''Given an iterable list of prices, standardize the prices
    Data is centered at 0 mean with unit variance

    :param x: price history
    :type x: (list, np.ndarray, pd.Series)
    :return: z-score standardized price history
    :rtype: np.ndarray
    '''

    assert isinstance(x, (list, np.ndarray, pd.Series))
    assert all(~np.isnan(i) for i in x)
    
    return stats.zscore(x)

def normalize_prices(x):
    '''Normalize an iterable list of prices to range (0,1)
    
    :param x: price history
    :type x: (list, np.ndarray, pd.Series)
    :return: normalized price history
    :rtype: np.ndarray
    '''
    assert isinstance(x, (list, np.ndarray, pd.Series))
    assert all(~np.isnan(i) for i in x)

    return (x-np.min(x))/(np.max(x) - np.min(x))

# %%
num = 19
product = pd.DataFrame(data=products_electronics_bs[num]['data']['AMAZON'], index=products_electronics_bs[num]['data']['AMAZON_time'], columns=['AMAZON'])
product = remove_nan(product)
product['Normalized'] = normalize_prices(product['AMAZON'])
# plt.plot(product['AMAZON_time'], normalize_prices(product['AMAZON']))
plt.plot(product.index, product.Normalized)
# num = 20
# product = pd.DataFrame(data=products_electronics_bs[num]['data']['AMAZON'], index=products_electronics_bs[num]['data']['AMAZON_time'], columns=['AMAZON'])
# product = remove_nan(product)
# product['Normalized'] = normalize_prices(product['AMAZON'])
# plt.plot(product.index, product.Normalized)
